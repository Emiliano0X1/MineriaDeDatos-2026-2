# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/googleplaystore.csv"
df = pd.read_csv(url)

# %% [markdown]
# Pregunta A: El scraper cometió errores y guardó la misma app varias veces. Escriban una línea de código para identificar si hay nombres duplicados en la columna App (df.duplicated(subset=['App']).sum()). Si los hay, apliquen .drop_duplicates(subset=['App'], keep='first', inplace=True) para quedarse solo con la primera aparición de cada aplicación

# %%
## Si hay registros duplicados
df.drop_duplicates(subset=['App'], keep='first', inplace=True)

res = df.duplicated(subset=['App']).sum()
print("Cantidad de duplicados: ", res)
# Out:
# Cantidad de duplicados:  0

# %% [markdown]
# ¿Cuántos registros duplicados purgaron?
#
# Fueron en total 1134 registros que fueron eliminados

# %% [markdown]
# Pregunta B: La columna Installs tiene texto como "1,000,000+". Un algoritmo no puede procesar eso.

# %% [markdown]
# a. Escriban una instrucción encadenando el método .str.replace() para eliminar el símbolo + y otro para eliminar la coma ,. (Ojo: utilicen regex=False o escapen el símbolo más \+).

# %%
df['Installs'] = df['Installs'].str.replace('+',"",regex=False)
df['Installs'] = df['Installs'].str.replace(',',"",regex=False)

df['Installs'] = pd.to_numeric(df['Installs'],errors = 'coerce') ##There some texts like Free that generate erros, so i passed as NaN cause theres no any value

print(df['Installs'])
# Out:
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10836        5000.0
# 10837         100.0
# 10838        1000.0
# 10839        1000.0
# 10840    10000000.0
# Name: Installs, Length: 9660, dtype: float64

# %% [markdown]
# b. Al final de la cadena, utilicen .astype(int) (o float si tienen NaNs) para convertir la columna.

# %%
df['Installs'] = df['Installs'].astype(float)
print(df['Installs'].dtype)
# Out:
# float64

# %% [markdown]
# Comprueben el éxito ejecutando df['Installs'].mean().
# ¿Cuál es el promedio real de descargas?
#
# El promedio de las descargas son de 7,777,506.73

# %%
average = df['Installs'].mean()
print("Downloads Average: ", average)
# Out:
# Downloads Average:  7777506.732270421

# %% [markdown]
# Pregunta C: La columna Price tiene valores como "$4.99" y "0". Apliquen la misma lógica arquitectónica que en la Pregunta B: eliminen el símbolo de dólar $ y conviertan la columna usando .astype(float).

# %%
##Same process - delete $ sign and convert to int or float
df['Price'] = df['Price'].str.replace('$','',regex=False)
df['Price'] = df['Price'].str.replace('.','',regex=False)

df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df['Price'] = df['Price'].astype(float)

print(df['Price'].dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 ##Same process - delete $ sign and convert to int or float
# ----> 2 df['Price'] = df['Price'].str.replace('$','',regex=False)
#       3 df['Price'] = df['Price'].str.replace('.','',regex=False)
#       5 df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
#
# File c:\Users\emili\miniconda3\envs\mineria_datos\lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File c:\Users\emili\miniconda3\envs\mineria_datos\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\emili\miniconda3\envs\mineria_datos\lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\emili\miniconda3\envs\mineria_datos\lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# Pregunta D: Ahora que el precio es numérico, ejecuten df['Price'].max(). Notarán que la app más cara cuesta alrededor de 400 dólares.

# %%
print("Price of the max app : ", df['Price'].max())
# Out:
# Price of the max app :  40000.0

# %% [markdown]
# a. Usen un filtro booleano (df[df['Price'] > 200]) para descubrir cuáles son estas apps. Verán que son aplicaciones basura o de broma.

# %%
print("Apps : ", df[df['Price'] > 20000])
# Out:
# Apps :                                      App   Category  Rating Reviews  Size  \
# 4197             most expensive app (H)     FAMILY     4.3       6  1.5M
# 4362                         💎 I'm rich  LIFESTYLE     3.8     718   26M
# 4367           I'm Rich - Trump Edition  LIFESTYLE     3.6     275  7.3M
# 5351                          I am rich  LIFESTYLE     3.8    3547  1.8M
# 5354                     I am Rich Plus     FAMILY     4.0     856  8.7M
# 5355                      I am rich VIP  LIFESTYLE     3.8     411  2.6M
# 5356                  I Am Rich Premium    FINANCE     4.1    1867  4.7M
# 5357                I am extremely Rich  LIFESTYLE     2.9      41  2.9M
# 5358                         I am Rich!    FINANCE     3.8      93   22M
# 5359                 I am rich(premium)    FINANCE     3.5     472  965k
# 5362                      I Am Rich Pro     FAMILY     4.4     201  2.7M
# 5364     I am rich (Most expensive app)    FINANCE     4.1     129  2.7M
# 5366                          I Am Rich     FAMILY     3.6     217  4.9M
# 5369                          I am Rich    FINANCE     4.3     180  3.8M
# 5373                 I AM RICH PRO PLUS    FINANCE     4.0      36   41M
# 9917                        Eu Sou Rico    FINANCE     NaN       0  1.4M
# 9934  I'm Rich/Eu sou Rico/أنا غني/我很有錢  LIFESTYLE     NaN       0   40M
#
#       Installs  Type    Price Content Rating         Genres  \
# 4197     100.0  Paid  39999.0       Everyone  Entertainment
# 4362   10000.0  Paid  39999.0       Everyone      Lifestyle
# 4367   10000.0  Paid  40000.0       Everyone      Lifestyle
# 5351  100000.0  Paid  39999.0       Everyone      Lifestyle
# 5354   10000.0  Paid  39999.0       Everyone  Entertainment
# 5355   10000.0  Paid  29999.0       Everyone      Lifestyle
# 5356   50000.0  Paid  39999.0       Everyone        Finance
# 5357    1000.0  Paid  37999.0       Everyone      Lifestyle
# 5358    1000.0  Paid  39999.0       Everyone        Finance
# 5359    5000.0  Paid  39999.0       Everyone        Finance
# 5362    5000.0  Paid  39999.0       Everyone  Entertainment
# 5364    1000.0  Paid  39999.0           Teen        Finance
# 5366   10000.0  Paid  38999.0       Everyone  Entertainment
# 5369    5000.0  Paid  39999.0       Everyone        Finance
# 5373    1000.0  Paid  39999.0       Everyone        Finance
# 9917       0.0  Paid  39499.0       Everyone        Finance
# 9934       0.0  Paid  39999.0       Everyone      Lifestyle
#
#            Last Updated Current Ver   Android Ver
# 4197      July 16, 2018         1.0    7.0 and up
# 4362     March 11, 2018       1.0.0    4.4 and up
# 4367        May 3, 2018       1.0.1    4.1 and up
# 5351   January 12, 2018         2.0  4.0.3 and up
# 5354       May 19, 2018         3.0    4.4 and up
# 5355      July 21, 2018       1.1.1    4.3 and up
# 5356  November 12, 2017         1.6    4.0 and up
# 5357       July 1, 2018         1.0    4.0 and up
# 5358  December 11, 2017         1.0    4.1 and up
# 5359        May 1, 2017         3.4    4.4 and up
# 5362       May 30, 2017        1.54    1.6 and up
# 5364   December 6, 2017           2  4.0.3 and up
# 5366      June 22, 2018         1.5    4.2 and up
# 5369     March 22, 2018         1.0    4.2 and up
# 5373      June 25, 2018       1.0.2    4.1 and up
# 9917      July 11, 2018         1.0  4.0.3 and up
# 9934   December 1, 2017       MONEY    4.1 and up

# %% [markdown]
# b. Si metemos estas apps al modelo, la red neuronal creerá que vender a 400 dólares es un modelo de negocio viable. Sobrescriban el DataFrame conservando únicamente las apps que cuesten menos de 50 dólares (df = df[df['Price'] < 50]).

# %%
df = df[df['Price'] < 5000]
print(df.size)
# Out:
# 125268

# %% [markdown]
# c.Guarden su dataset final usando df.to_csv('playstore_limpio.csv', index=False).

# %%
df.to_csv('playstore_limpio.csv', index= False)
